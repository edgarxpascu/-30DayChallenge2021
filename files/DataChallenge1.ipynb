# %% [markdown]
# # Day 5 Data challenge 1: OpenStreetMap
# ### To make it more interesting, my idea was to do everything in Python (this is the first map outside QGIS). Generating a very simple map, but full of learning. That leads me to making this repository.
# Recognition to OpenStreetMap and especially to its collaborators in Mexico.

# %%
import matplotlib.pyplot as plt 
import os
import geopandas as gpd
import osmnx as ox

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
# Desired styling for matplotlib
from matplotlib import cycler
colors = cycler('color',["44aa98","ab4498","332389","86ccec","ddcc76","cd6477","882255", "117732"])
plt.rcParams['figure.figsize'] = [6,4]
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False
plt.rcParams['text.color'] = '212121'
plt.rcParams['xtick.color'] = '212121'
plt.rcParams['ytick.color'] = '212121'
plt.rcParams['font.family'] = 'sans serif'
plt.rcParams['axes.facecolor'] = 'None'
plt.rcParams['axes.edgecolor'] = 'dimgray'
plt.rcParams['axes.grid'] = False
plt.rcParams['axes.grid'] = False
plt.rcParams['grid.color'] = 'lightgray'
plt.rcParams['grid.linestyle'] = 'dashed'
plt.rcParams['xtick.labelsize'] = 'x-small'
plt.rcParams['ytick.labelsize'] = 'x-small'
plt.rcParams['legend.frameon'] = True
plt.rcParams['legend.framealpha'] = 0.8
plt.rcParams['legend.facecolor'] = 'white'
plt.rcParams['legend.edgecolor'] = 'None'
plt.rcParams['legend.fontsize'] = 'medium'
plt.rcParams['axes.labelsize'] = 'small'
plt.rcParams['savefig.facecolor'] = 'None'
plt.rcParams['savefig.edgecolor'] = 'None'
plt.rc('axes', prop_cycle=colors)

# %%
place_name = "National Autonomous University of Mexico"
area = ox.geocode_to_gdf(place_name)
buildings = ox.geometries_from_place(place_name, tags={'building':True})

# %%
fig, ax = plt.subplots(figsize=(22,11), facecolor="#14213d")

# Plot buildings
area.geometry.plot(ax=ax, facecolor="#515A47", edgecolor="#DDEDAA", linewidth=0.05)
buildings.geometry.plot(ax=ax, facecolor="#D7BE82", edgecolor="#DDEDAA", linewidth=0.05)

ax.axis('off')
ax.annotate(f"Edificios en: \n", xy=(0.5,1), xycoords='axes fraction', color="#7A4419", ha='right', fontsize="xx-large")
ax.annotate(f"\n {place_name}" , xy=(0.5,1), xycoords='axes fraction', color='#FEA82F', ha='center', fontsize="xx-large")

ax.annotate(f"© OpenStreetMap contributors", xy=(1, 0), xycoords='axes fraction', color="#FEA82F", ha='right', fontsize="small")

plt.savefig('DC_OSM.png', facecolor="#14213d", dpi = 300, bbox_inches='tight')
# Out:
# C:\Users\edgar\AppData\Roaming\Python\Python39\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
